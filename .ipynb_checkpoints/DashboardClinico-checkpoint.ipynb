# %%
import dash
import plotly.express as px
import plotly.graph_objects as go
import dash_bootstrap_components as dbc
import pandas as pd
from dash import html, dcc, Input, Output
import plotly.io as pio

# Tema obscuro
pio.templates.default = "plotly_dark"

# =========================
df = pd.read_csv('./clinical_analytics.csv')

# %%
df['Wait Time Min'] = pd.to_numeric(df['Wait Time Min'], errors='coerce')
df['Care Score'] = pd.to_numeric(df['Care Score'], errors='coerce')
df = df.dropna(subset=['Wait Time Min', 'Care Score'])

# Convertir Check-In Time a datetime con formato especificado
df['Check-In Time'] = pd.to_datetime(
    df['Check-In Time'],
    format='%Y-%m-%d %I:%M:%S %p',
    errors='coerce'
)
df['Check-In Date'] = df['Check-In Time'].dt.date
df['Check-In Month'] = df['Check-In Time'].dt.to_period('M')

# Limpiar Admit Source - reemplazar NaN con "Unknown"
df['Admit Source'] = df['Admit Source'].fillna('Unknown')

negative_count = (df['Wait Time Min'] < 0).sum()
df = df[df['Wait Time Min'] >= 0]

# %%
# COLORES
BG = "#2b2b2b"
CARD = "#3a3a3a"
BLUE = "#4dabf7"
TEXT = "#a5d8ff"

# APP
app = dash.Dash(external_stylesheets=[dbc.themes.DARKLY])

def kpi_card(title, id_value):
    return dbc.Card(
        dbc.CardBody([
            html.P(title, style={"color": TEXT}),
            html.H3(id=id_value, style={"color": BLUE}),
        ]),
        style={
            "backgroundColor": CARD,
            "borderRadius": "10px"
        }
    )

# %%
# LAYOUT

app.layout = dbc.Container(fluid=True, children=[

    dbc.Row([

        # SIDEBAR
        dbc.Col([
            html.H4("🏥 Clínica", style={"color": BLUE}),
            html.Hr(),

            html.Label("Departamento", style={"color": TEXT}),
            dcc.Dropdown(
                id="department-filter",
                options=[{'label': x, 'value': x} for x in df['Department'].unique()],
                value=df['Department'].unique(),
                multi=True
            ),

            html.Br(),

            html.Label("Tipo Admisión", style={"color": TEXT}),
            dcc.Dropdown(
                id="admit-type-filter",
                options=[{'label': x, 'value': x} for x in df['Admit Type'].unique()],
                value=df['Admit Type'].unique(),
                multi=True
            ),

            html.Br(),

            html.Label("Fuente", style={"color": TEXT}),
            dcc.Dropdown(
                id="admit-source-filter",
                options=[{'label': x, 'value': x} for x in df['Admit Source'].unique()],
                value=df['Admit Source'].unique(),
                multi=True
            ),

            html.Br(),

            html.Label("Tiempo de Espera", style={"color": TEXT}),
            dcc.RangeSlider(
                id="wait-filter",
                min=df['Wait Time Min'].min(),
                max=df['Wait Time Min'].max(),
                value=[df['Wait Time Min'].min(), df['Wait Time Min'].max()],
            ),

        ], width=2, style={
            "backgroundColor": "#6E6E6E",
            "height": "100vh",
            "padding": "15px",
            "position": "fixed"
        }),
        
        # CONTENIDO
        dbc.Col([

            html.H2("Dashboard Clínico", style={"color": BLUE}),
            html.P("Análisis de operaciones", style={"color": TEXT}),

            dbc.Alert(
                f"Nota: Se encontraron {negative_count} registros con tiempos de espera negativos (pacientes que llegaron tarde) y fueron excluidos del análisis.",
                color="warning",
                className="mb-3"
            ) if negative_count > 0 else html.Div(),
            
            # KPIs
            dbc.Row([
                dbc.Col(kpi_card("Tiempo Promedio", "avg-wait"), md=3),
                dbc.Col(kpi_card("Care Score", "avg-care"), md=3),
                dbc.Col(kpi_card("Registros", "total-rec"), md=3),
                dbc.Col(kpi_card("Clínicas", "clinics"), md=3),
            ], className="mb-4"),

            # FILA 1
            dbc.Row([
                dbc.Col(dcc.Graph(id="scatter"), md=6),
                dbc.Col(dcc.Graph(id="bar-dept"), md=6),
            ]),

            # FILA 2
            dbc.Row([
                dbc.Col(dcc.Graph(id="hist"), md=6),
                dbc.Col(dcc.Graph(id="timeline"), md=6),
            ]),

            # FILA 3
            dbc.Row([
                dbc.Col(dcc.Graph(id="dual-bar"), md=12),
            ]),

            # FILA 4
            dbc.Row([
                dbc.Col(dcc.Graph(id="box"), md=6),
                dbc.Col(dcc.Graph(id="heatmap"), md=6),
            ]),

            # FILA 5
            dbc.Row([
                dbc.Col(dcc.Graph(id="clinic-bar"), md=6),
                dbc.Col(dcc.Graph(id="status-bar"), md=6),
            ]),

            dbc.Row([
                dbc.Col(html.Div(id="insight-box", style={"color": TEXT}))
            ])

        ], width={"size": 10, "offset": 2}, style={
            "backgroundColor": BG,
            "padding": "20px",
            "minHeight": "100vh"
        })

    ])
])

# %%
#  CALLBACK

@app.callback(
    [
        Output("scatter", "figure"),
        Output("bar-dept", "figure"),
        Output("hist", "figure"),
        Output("timeline", "figure"),
        Output("dual-bar", "figure"),
        Output("box", "figure"),
        Output("heatmap", "figure"),
        Output("clinic-bar", "figure"),
        Output("status-bar", "figure"),
        Output("avg-wait", "children"),
        Output("avg-care", "children"),
        Output("total-rec", "children"),
        Output("clinics", "children"),
        Output("insight-box", "children"),
    ],
    [
        Input("department-filter", "value"),
        Input("admit-type-filter", "value"),
        Input("admit-source-filter", "value"),
        Input("wait-filter", "value"),
    ]
)
def update(dept, admit, source, wait):

    dff = df[
        (df['Department'].isin(dept)) &
        (df['Admit Type'].isin(admit)) &
        (df['Admit Source'].isin(source)) &
        (df['Wait Time Min'].between(wait[0], wait[1]))
    ]

    #  Sinteti
    if dff.empty:
        empty = go.Figure()
        return [empty]*9 + ["0","0","0","0","Sin datos"]

    # SCATTER TIEMPO ESPERA VS PUNTUACION
    scatter = px.scatter(dff, 
        x="Wait Time Min", 
        y="Care Score", 
        size="Care Score", 
        color="Department", 
        title="Tiempo de Espera vs. Puntuación por Departamento",
        labels={
            "Wait Time Min": "Tiempo de Espera (min)",
            "Care Score": "Puntuación de Atención"
        })

    # BAR CASOS X DEP
    top_dept = dff['Department'].value_counts().nlargest(10).reset_index()
    top_dept.columns = ['Department', 'Count']
    bar_dept = px.bar(top_dept, 
        x="Count", 
        y="Department", 
        orientation="h", 
        title="Distribución de casos por departamento", 
        color="Department", 
        color_discrete_sequence=px.colors.qualitative.Safe,
        labels={
        "Count": "Casos",
        "Department": "Departamento"
    })
    bar_dept.update_layout(yaxis={'categoryorder':'total ascending'}, showlegend=False)

    # HIST TIEMPOS ESPERA
    hist = px.histogram(
        dff, 
        x="Wait Time Min", 
        color="Encounter Status", 
        title="Distribución de Tiempos de Espera",
        labels={"Wait Time Min": "Tiempo de Espera (min)", "count": "Frecuencia"}
    )

    # TIMELINE PACIENTES X MES
    timeline_df = dff.groupby('Check-In Month').size().reset_index(name='Cantidad')
    timeline_df['Check-In Month'] = timeline_df['Check-In Month'].astype(str)
    timeline = px.line(
        timeline_df, 
        x="Check-In Month", 
        y="Cantidad",
        title='Volumen de Pacientes por Mes',
        labels={'Check-In Month': 'Mes', 'Cantidad': 'Número de Pacientes'},
    )

    # DUAL PACIENTES X TIEMPO ESPERA
    stats = dff.groupby('Admit Source').agg({
        'Wait Time Min':'mean',
        'Encounter Number':'count'
    }).reset_index()

    dual = go.Figure()
    dual.add_trace(go.Bar(x=stats['Admit Source'], y=stats['Encounter Number']))
    dual.add_trace(go.Scatter(x=stats['Admit Source'], y=stats['Wait Time Min'], yaxis="y2"))
    dual.update_layout(
        yaxis=dict(title="Número de Pacientes (Barras)"),
        yaxis2=dict(title="Espera Promedio min (Línea)", overlaying='y', 
        side='right'),
        title="Volumen de Pacientes vs Tiempo de Espera",
        showlegend=False
    )

    # BOX TIEMPO X DEP
    box = px.box(
        dff, 
        x="Department", 
        y="Wait Time Min",
        color="Department",
        points="outliers",
        title="Variabilidad de Espera por Departamento",
        labels={'Wait Time Min': 'Tiempo (minutos)', 'Department': 'Departamento'}
    )

    # HEATMAP ATENCION
    #Creamos variables numéricas nuevas a partir del tiempo
    dff['Check-In Hour'] = dff['Check-In Time'].dt.hour
    dff['Day of Week'] = dff['Check-In Time'].dt.dayofweek 
    
    columnas_analisis = ['Wait Time Min', 'Care Score', 'Check-In Hour', 'Day of Week']
    corr = dff[columnas_analisis].corr()

    #Renombramos los índices y columnas de la matriz para el gráfico
    nombres_amigables = {
        'Wait Time Min': 'Tiempo de espera (minutos)',
        'Care Score': 'Puntuación',
        'Check-In Hour': 'Hora de ingreso',
        'Day of Week': 'Día de la semana'
    }
    corr.rename(columns=nombres_amigables, index=nombres_amigables, inplace=True)

    heatmap = px.imshow(
        corr, 
        text_auto=".2f", 
        color_continuous_scale='RdBu_r', 
        zmin=-1, zmax=1,
        title="Análisis de Correlación: Factores de Atención",
        labels=dict(color="Correlación")
    )


    # BAR TIEMPO X CLINICAS
    clinic = dff.groupby('Clinic Name')['Wait Time Min'].mean().reset_index()
    clinic = clinic.sort_values(by='Wait Time Min', ascending=False).head(10)
    clinic_bar = px.bar(
        clinic, 
        x="Wait Time Min", 
        y="Clinic Name", 
        orientation="h",
        title="Clínicas vs. Tiempo de Espera (Promedio)",
        color="Wait Time Min",              # El color cambia según el tiempo
        color_continuous_scale="Reds",      # Degradado de rojo para resaltar las más lentas
        text_auto='.1f'               
    )
    clinic_bar.update_layout(
    xaxis_title="Tiempo de Espera Promedio (Minutos)",
    yaxis_title="Clínica",
    coloraxis_showscale=False,
    # Ajustamos el rango del eje X para que empiece un poco antes del mínimo para que las diferencias pequeñas se vean mucho más grandes
    xaxis=dict(range=[clinic['Wait Time Min'].min() - 0.5, clinic['Wait Time Min'].max() + 0.5])
    )

    # STATUS CITAS X DEP
    status_bar = px.histogram(
        dff, 
        x="Department", 
        color="Encounter Status",
        barnorm='percent',
        title="Estados de Citas por Departamento",
        text_auto=True,
        labels={
        "Encounter Status": "Estado de Cita"
        }
    )

    status_bar.update_layout(
    yaxis_title="Total (en porcentaje)",
    xaxis_title="Departamento"
    )

    # KPIs
    avg_wait = f"{dff['Wait Time Min'].mean():.1f}"
    avg_care = f"{dff['Care Score'].mean():.2f}"
    total = f"{len(dff):,}"
    clinics = f"{dff['Clinic Name'].nunique()}"

    insight = "Dashboard funcionando correctamente ✔"

    return (
        scatter, bar_dept, hist, timeline, dual,
        box, heatmap, clinic_bar, status_bar,
        avg_wait, avg_care, total, clinics, insight
    )

# %%
# =========================
# RUN
# =========================
if __name__ == "__main__":
    app.run(debug=True, port=8060)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8060/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
